# %%
import pandas as pd

# %%
file_path = r'D:\Work\python\2000 LARGEST CAMPANIES\largest campanies 2022.xlsx'
df = pd.read_excel(file_path)

# %%
df
# Out:
#       Unnamed: 0                                           Name  \
# 0              0                                  JPMorganChase
# 1              1                             Berkshire Hathaway
# 2              2       Saudi Arabian Oil Company (Saudi Aramco)
# 3              3                                           ICBC
# 4              4                                Bank of America
# ...          ...                                            ...
# 1996        1996                        Sichuan Chuantou Energy
# 1997        1997  Vietnam Prosperity Joint-sock Commercial Bank
# 1998        1998                                         Adient
# 1999        1999                          CapitaLand Investment
# 2000        2000                     Shanxi Lu'an Environmental
#
#             Country     Sales    Profit      Assets Market Value
# 0     United States  $252.9 B     $50 B  $4,090.7 B     $588.1 B
# 1     United States    $369 B   $73.4 B    $1,070 B     $899.1 B
# ...

# %%
def convert_to_billions(sales):
    # Strip any leading or trailing whitespace
    sales = sales.strip()
    sales = sales.replace(',', '')

    
    if 'B' in sales:
        return float(sales.replace('$', '').replace(' B', '').strip())
    elif 'M' in sales:
        return float(sales.replace('$', '').replace('M', '').strip()) / 1000
    else:
        raise ValueError("Unknown format")

# Apply the conversion function to the 'sales' column
df['assets_in_billions'] = df['Assets'].apply(convert_to_billions)
df['marketValue_in_billions']=df['Market Value'].apply(convert_to_billions)
df['profit_in_billions']= df['profit'].apply(convert_to_billions)
df['sales_in_billions']= df['Sales'].apply(convert_to_billions)



df
# Out:
#       Unnamed: 0                                           Name  \
# 0              0                                  JPMorganChase
# 1              1                             Berkshire Hathaway
# 2              2       Saudi Arabian Oil Company (Saudi Aramco)
# 3              3                                           ICBC
# 4              4                                Bank of America
# ...          ...                                            ...
# 1996        1996                        Sichuan Chuantou Energy
# 1997        1997  Vietnam Prosperity Joint-sock Commercial Bank
# 1998        1998                                         Adient
# 1999        1999                          CapitaLand Investment
# 2000        2000                     Shanxi Lu'an Environmental
#
#             Country     Sales    Profit      Assets Market Value  \
# 0     United States  $252.9 B     $50 B  $4,090.7 B     $588.1 B
# ...

# %%
df
# Out:
#       rank                                      global company        country  \
# 0         1                                 Berkshire Hathaway  United States
# 1         2                                               ICBC          China
# 2         3           Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia
# 3         4                                     JPMorgan Chase  United States
# 4         5                            China Construction Bank          China
# ...     ...                                                ...            ...
# 1995   1995  Shenzhen Feima International Supply Chain Co.,...          China
# 1996   1997                                               NMDC          India
# 1997   1997                         Sichuan Changhong Electric          China
# 1998   1999                              Credit Bank of Moscow         Russia
# 1999   1999                                 Satellite Chemical          China
#
# ...

# %%
import os 
#urpose: This function retrieves the directory name from the full file path specified in file_path.
#Example: If file_path is r'D:\Work\python\2000 LARGEST CAMPANIES\largest campanies 2022.xlsx', then os.path.dirname(file_path) will return r'D:\Work\python\2000 LARGEST CAMPANIES'.
output_file_name = 'largest_companies_2022_processed.xlsx'  # Name of the new file
output_path = os.path.join(os.path.dirname(file_path), output_file_name)

# Save the modified DataFrame to a new Excel file
try:
    df.to_excel(output_path, index=False)  # Set index=False to avoid writing row indices
    print(f"DataFrame saved to {output_path}")
except PermissionError as e:
    print(f"Permission error: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# DataFrame saved to D:\Work\python\2000 LARGEST CAMPANIES\largest_companies_2022_processed.xlsx
